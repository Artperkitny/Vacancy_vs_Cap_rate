# %%
import seaborn

# %%
import matplotlib
matplotlib.use('TkAgg')
# %matplotlib inline
import pandas as pd
import geopandas as gp
import matplotlib.pyplot as plt
import contextily as ctx

# %%
df = pd.read_csv("_select_count_geo_id_as_sample_size_round_cast_vacant_rentals_pe_201907292327.csv")

# %%
df_cleaned = df[df["sample_size"]>=100]

# %%
df_cleaned.plot.scatter(
    x="vacancy_percentage",
    y="median_cap_rate",
    figsize=(14,14)
)

# %%
df_cleaned.plot.scatter(
    x="vacancy_percentage",
    y="median_rent_to_price_ratio",
    figsize=(14,14)
)

# %%
seaborn.regplot(
    x=df_cleaned["vacancy_percentage"],
    y=df_cleaned["median_cap_rate"],
    marker="*",
)

# %%
seaborn.regplot(
    x=df["vacancy_percentage"],
    y=df["median_cap_rate"],
    marker="*",
)

# %%
df_cleaned.vacancy_percentage.min()
# Out:
# 0.80000000000000004

# %%
df_cleaned[["sample_size","vacancy_percentage","median_cap_rate"]].to_csv("cap_rate_vs_vacancy.csv")
